# %%
# Import libraries

import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Import dataset

house = pd.read_csv('data.csv')
house.head()
# Out:
#            id             date     price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  20141013T000000  221900.0         3       1.00         1180
# 1  6414100192  20141209T000000  538000.0         3       2.25         2570
# 2  5631500400  20150225T000000  180000.0         2       1.00          770
# 3  2487200875  20141209T000000  604000.0         4       3.00         1960
# 4  1954400510  20150218T000000  510000.0         3       2.00         1680
#
#    sqft_lot  floors  waterfront  view  ...  grade  sqft_above  sqft_basement  \
# 0      5650     1.0           0     0  ...      7        1180              0
# 1      7242     2.0           0     0  ...      7        2170            400
# 2     10000     1.0           0     0  ...      6         770              0
# 3      5000     1.0           0     0  ...      7        1050            910
# 4      8080     1.0           0     0  ...      8        1680              0
#
# ...

# %%
house.shape
# Out:
# (21613, 21)

# %%
house.describe()
# Out:
#                  id         price      bedrooms     bathrooms   sqft_living  \
# count  2.161300e+04  2.161300e+04  21613.000000  21613.000000  21613.000000
# mean   4.580302e+09  5.400881e+05      3.370842      2.114757   2079.899736
# std    2.876566e+09  3.671272e+05      0.930062      0.770163    918.440897
# min    1.000102e+06  7.500000e+04      0.000000      0.000000    290.000000
# 25%    2.123049e+09  3.219500e+05      3.000000      1.750000   1427.000000
# 50%    3.904930e+09  4.500000e+05      3.000000      2.250000   1910.000000
# 75%    7.308900e+09  6.450000e+05      4.000000      2.500000   2550.000000
# max    9.900000e+09  7.700000e+06     33.000000      8.000000  13540.000000
#
#            sqft_lot        floors    waterfront          view     condition  \
# count  2.161300e+04  21613.000000  21613.000000  21613.000000  21613.000000
# mean   1.510697e+04      1.494309      0.007542      0.234303      3.409430
# ...

# %%
house.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21613 entries, 0 to 21612
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   id             21613 non-null  int64
#  1   date           21613 non-null  object
#  2   price          21613 non-null  float64
#  3   bedrooms       21613 non-null  int64
#  4   bathrooms      21613 non-null  float64
#  5   sqft_living    21613 non-null  int64
#  6   sqft_lot       21613 non-null  int64
#  7   floors         21613 non-null  float64
#  8   waterfront     21613 non-null  int64
#  9   view           21613 non-null  int64
#  10  condition      21613 non-null  int64
#  11  grade          21613 non-null  int64
#  12  sqft_above     21613 non-null  int64
#  13  sqft_basement  21613 non-null  int64
#  14  yr_built       21613 non-null  int64
#  15  yr_renovated   21613 non-null  int64
#  16  zipcode        21613 non-null  int64
# ...

# %%
house.columns
# Out:
# Index(['id', 'date', 'price', 'bedrooms', 'bathrooms', 'sqft_living',
#        'sqft_lot', 'floors', 'waterfront', 'view', 'condition', 'grade',
#        'sqft_above', 'sqft_basement', 'yr_built', 'yr_renovated', 'zipcode',
#        'lat', 'long', 'sqft_living15', 'sqft_lot15'],
#       dtype='object')

# %%
# check for duplicated rows

house.duplicated().sum()
# Out:
# 0

# %%
house.isnull().sum()
# Out:
# id               0
# date             0
# price            0
# bedrooms         0
# bathrooms        0
# sqft_living      0
# sqft_lot         0
# floors           0
# waterfront       0
# view             0
# condition        0
# grade            0
# sqft_above       0
# sqft_basement    0
# yr_built         0
# yr_renovated     0
# zipcode          0
# lat              0
# long             0
# sqft_living15    0
# sqft_lot15       0
# dtype: int64

# %%
house.nunique()
# Out:
# id               21436
# date               372
# price             4028
# bedrooms            13
# bathrooms           30
# sqft_living       1038
# sqft_lot          9782
# floors               6
# waterfront           2
# view                 5
# condition            5
# grade               12
# sqft_above         946
# sqft_basement      306
# yr_built           116
# yr_renovated        70
# zipcode             70
# lat               5034
# long               752
# sqft_living15      777
# sqft_lot15        8689
# dtype: int64

# %%
house.corr()
# Out:
# /var/folders/_l/rvfsqjvn4fl7npqhjz_rd08h0000gn/T/ipykernel_4114/3588287297.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   house.corr()
#                      id     price  bedrooms  bathrooms  sqft_living  sqft_lot  \
# id             1.000000 -0.016762  0.001286   0.005160    -0.012258 -0.132109
# price         -0.016762  1.000000  0.308350   0.525138     0.702035  0.089661
# bedrooms       0.001286  0.308350  1.000000   0.515884     0.576671  0.031703
# bathrooms      0.005160  0.525138  0.515884   1.000000     0.754665  0.087740
# sqft_living   -0.012258  0.702035  0.576671   0.754665     1.000000  0.172826
# sqft_lot      -0.132109  0.089661  0.031703   0.087740     0.172826  1.000000
# floors         0.018525  0.256794  0.175429   0.500653     0.353949 -0.005201
# ...

# %%
sns.heatmap(house.corr())
# Out:
# /var/folders/_l/rvfsqjvn4fl7npqhjz_rd08h0000gn/T/ipykernel_4114/4108276498.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(house.corr())
# <Axes: >

# %%
feature = ['price','bedrooms','bathrooms','sqft_living','view','grade','sqft_above','yr_built','yr_renovated','sqft_living15']

house_df = house[feature]

# %%
# Relationships between variables

sns.pairplot(house_df)

# %%
# Set Seaborn style
sns.set_style("darkgrid")
 
# Identify numerical columns
numerical_columns = house_df.select_dtypes(include=["int64", "float64"]).columns
 
# Plot distribution of each numerical feature
plt.figure(figsize=(14, len(numerical_columns) * 3))
for idx, feature in enumerate(numerical_columns, 1):
    plt.subplot(len(numerical_columns), 2, idx)
    sns.histplot(house_df[feature], kde=True)
    plt.title(f"{feature} | Skewness: {round(house_df[feature].skew(), 2)}")

plt.tight_layout()
plt.show()

# %%
# categorical variables

# in counts

house_df.view.value_counts()
# Out:
# 0    19489
# 2      963
# 3      510
# 1      332
# 4      319
# Name: view, dtype: int64

# %%
# in percentages

house_df.view.value_counts(normalize=True)
# Out:
# 0    0.901726
# 2    0.044557
# 3    0.023597
# 1    0.015361
# 4    0.014760
# Name: view, dtype: float64

# %%
house_df.view.value_counts().plot(kind='bar')
plt.title('Value counts of the target variable')
plt.xlabel('Views')
plt.xticks(rotation=0)
plt.ylabel('Count')
plt.show()

# %%
house_df.view.value_counts(normalize=True).plot(kind='bar')
plt.title('Value counts of the target variable')
plt.xlabel('Numbers of floors')
plt.xticks(rotation=0)
plt.ylabel('Percentage')
plt.show()

# %%
# numeric variables

house_df.price.describe()
# Out:
# count    2.161300e+04
# mean     5.400881e+05
# std      3.671272e+05
# min      7.500000e+04
# 25%      3.219500e+05
# 50%      4.500000e+05
# 75%      6.450000e+05
# max      7.700000e+06
# Name: price, dtype: float64

# %%
house_df.price.value_counts().plot(kind='hist')
plt.title('Distribution of housing price')
plt.xlabel('Price')
plt.xticks(rotation=0)
plt.ylabel('Frequency')
plt.show()

# %%
print(f"Skewness: {house_df['price'].skew()}")
print(f"Kurtosis: {house_df['price'].kurt()}")
# Out:
# Skewness: 4.024069144684712
# Kurtosis: 34.58554043194243

# %%
# boxplot - # of floors (categorical) vs price (numerical)

sns.catplot(x='view', y ='price', data=house_df, kind='box', aspect=1.5)
plt.title('Boxplot for view vs price')
plt.show()

# %%
plt.figure(figsize=(15, 10))
 
# Using Seaborn to create a heatmap
sns.heatmap(house_df.corr(), annot=True, fmt='.2f', cmap='Pastel2', linewidths=2)
 
plt.title('Correlation Heatmap')
plt.show()

# %%
# Define x and y variables

new_feature = ['bedrooms','bathrooms','sqft_living','view','grade','sqft_above','yr_built','yr_renovated','sqft_living15']

x = house_df[new_feature]
y = house_df['price']

# %%
x.head()
# Out:
#    bedrooms  bathrooms  sqft_living  view  grade  sqft_above  yr_built  \
# 0         3       1.00         1180     0      7        1180      1955
# 1         3       2.25         2570     0      7        2170      1951
# 2         2       1.00          770     0      6         770      1933
# 3         4       3.00         1960     0      7        1050      1965
# 4         3       2.00         1680     0      8        1680      1987
#
#    yr_renovated  sqft_living15
# 0             0           1340
# 1          1991           1690
# 2             0           2720
# 3             0           1360
# 4             0           1800

# %%
y.head()
# Out:
# 0    221900.0
# 1    538000.0
# 2    180000.0
# 3    604000.0
# 4    510000.0
# Name: price, dtype: float64

# %%
# Setting up the model

from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split

train_x,val_x,train_y,val_y = train_test_split(x,y)
linear_model = LinearRegression()
linear_model.fit(train_x,train_y)
# Out:
# LinearRegression()

# %%
train_x
# Out:
#        bedrooms  bathrooms  sqft_living  view  grade  sqft_above  yr_built  \
# 2323          3       1.00         1430     0      7        1430      1949
# 3331          5       1.75         1320     0      7        1120      1947
# 7522          3       2.50         2280     0      8        2280      2004
# 10778         3       1.75         2000     0      8        1320      1972
# 6043          4       1.75         2100     0      8        2100      1909
# ...         ...        ...          ...   ...    ...         ...       ...
# 1413          6       3.75         2740     2      7        1640      1962
# 11163         4       2.50         2410     0      8        2410      1993
# 9861          4       2.50         3110     3     10        3110      1984
# 15962         4       2.50         2610     0      8        2610      2005
# 2547          3       3.25         3230     0      9        3230      2006
#
#        yr_renovated  sqft_living15
# ...

# %%
train_y
# Out:
# 2323     552500.0
# 3331     380000.0
# 7522     470000.0
# 10778    410000.0
# 6043     750000.0
#            ...
# 1413     585444.0
# 11163    608000.0
# 9861     960000.0
# 15962    350000.0
# 2547     715000.0
# Name: price, Length: 16209, dtype: float64

# %%
val_x
# Out:
#        bedrooms  bathrooms  sqft_living  view  grade  sqft_above  yr_built  \
# 8639          3       1.75         1610     0      8        1310      1960
# 15689         3       2.25         1630     0      8        1100      1977
# 9674          3       1.00         1290     0      6         790      1929
# 10680         2       1.50         1010     0      7        1010      1981
# 19993         2       1.50         1130     0      8         910      2008
# ...         ...        ...          ...   ...    ...         ...       ...
# 5157          3       1.00          910     0      7         910      1969
# 1513          2       1.00          700     0      6         700      1951
# 6483          4       1.75         1710     0      7        1710      1955
# 10147         3       2.00         1190     0      6        1190      1907
# 18890         4       2.50         3030     0     10        3030      1988
#
#        yr_renovated  sqft_living15
# ...

# %%
val_y
# Out:
# 8639      430000.0
# 15689     305000.0
# 9674      450000.0
# 10680     306888.0
# 19993     439108.0
#            ...
# 5157      169000.0
# 1513      190000.0
# 6483      525000.0
# 10147     245000.0
# 18890    1050000.0
# Name: price, Length: 5404, dtype: float64

# %%
# Model Evaluation

print(linear_model.intercept_)
# Out:
# 6289018.674134769

# %%
coeff_df = pd.DataFrame(linear_model.coef_, x.columns, columns=['Coefficient'])
coeff_df
# Out:
#                  Coefficient
# bedrooms       -38985.466605
# bathrooms       53195.848614
# sqft_living       153.651368
# view            72360.973359
# grade          119314.045745
# sqft_above          5.526658
# yr_built        -3565.423489
# yr_renovated       19.420416
# sqft_living15      17.755599

# %%
# Make predictions from model

predictions = linear_model.predict(val_x)
plt.scatter(val_y, predictions)

# %%
sns.displot((val_y-predictions), bins=20)

# %%
# Evaluations

from sklearn import metrics

print('MAE:', metrics.mean_absolute_error(val_y, predictions))
print('MSE:', metrics.mean_squared_error(val_y, predictions))
print('RMSE:', np.sqrt(metrics.mean_squared_error(val_y, predictions)))
# Out:
# MAE: 144197.75089777814
# MSE: 51157946257.22084
# RMSE: 226181.22436935574
